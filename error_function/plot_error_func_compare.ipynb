# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from datetime import datetime

# %%
current_time = datetime.now()

# Format the time as "Hour:Minute AM/PM"
formatted_time = current_time.strftime("%I:%M %p")

print("Formatted time:", formatted_time)
# Out:
# Formatted time: 04:55 PM

# %%
# read
# n_LF, n_HF, rel_error = np.loadtxt('error_function_11P_MF-Box.txt', unpack=True, usecols=(0,1,2))
n_LF, n_HF, rel_error = np.loadtxt('error_function_goku_pre_frontera.txt', unpack=True, usecols=(0,1,2))

# %%
rel_error.shape
# Out:
# (2673,)

# %%
def grid_error(n_LF, n_HF, rel_error, n_LF_max = 270, n_HF_max = 9, len_slice = 3):
    X_grid = int(n_LF_max / len_slice)
    Y_grid = int(n_HF_max / len_slice)
    grid_error = np.ones((X_grid, Y_grid))
    n_sample = np.ones((X_grid, Y_grid))
    x = n_HF/len_slice
    y = n_LF/len_slice
    for i in range(len(x)):
        i_y = int(x[i]) - 1
        i_x = int(y[i]) - 1
        if grid_error[i_x, i_y] != 1:
            grid_error[i_x, i_y] += rel_error[i]
            n_sample[i_x, i_y] += 1
        else:
            grid_error[i_x, i_y] = rel_error[i]

    grid_error = grid_error/n_sample
    return grid_error

# %%
n_LF_max = 297
n_HF_max = 27
len_slice = 3

y = np.linspace(len_slice, n_LF_max, n_LF_max//len_slice)  # Replace with your desired range and resolution
x = np.linspace(len_slice, n_HF_max, n_HF_max//len_slice)  # Replace with your desired range and resolution
X, Y = np.meshgrid(x, y)

# create griddata
Z = grid_error(n_LF, n_HF, rel_error, len_slice=len_slice, n_LF_max=n_LF_max, n_HF_max=n_HF_max)

# Create a colormap to map function values to colors
cmap = plt.get_cmap('viridis')
vmin = 1e-2
vmax = 1

# Create a plot
plt.figure(figsize=(3, 12))
plt.pcolormesh(X, Y, Z, cmap=cmap, norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax))
plt.colorbar(label='Relative error')
plt.title('Error function')
plt.xlabel(r'$n_\mathrm{HF}$')
plt.ylabel(r'$n_\mathrm{LF}$')
xticks = np.arange(3, n_HF_max + 1, 3)
plt.xticks(xticks)
y_ticks = np.arange(6, n_LF_max + 1, 6)
plt.yticks(y_ticks)
plt.show()

# %%
Z.shape
# Out:
# (99, 9)

# %%
X.shape
# Out:
# (99, 9)

# %%
pairs_done = []
for row in range(Z.shape[0]):
    for col in range(Z.shape[1]):
        if Z[row, col] != 1:
            pairs_done.append([3*(row+1), 3*(col+1)])

# %%
len(pairs_done)
# Out:
# 891

# %%
pairs_done
# Out:
# [[3, 3],
#  [3, 6],
#  [3, 9],
#  [3, 12],
#  [3, 15],
#  [3, 18],
#  [3, 21],
#  [3, 24],
#  [3, 27],
#  [6, 3],
#  [6, 6],
#  [6, 9],
#  [6, 12],
#  [6, 15],
#  [6, 18],
#  [6, 21],
#  [6, 24],
#  [6, 27],
#  [9, 3],
#  [9, 6],
#  [9, 9],
#  [9, 12],
#  [9, 15],
#  [9, 18],
#  [9, 21],
#  [9, 24],
#  [9, 27],
#  [12, 3],
#  [12, 6],
#  [12, 9],
#  [12, 12],
#  [12, 15],
#  [12, 18],
#  [12, 21],
#  [12, 24],
#  [12, 27],
#  [15, 3],
#  [15, 6],
#  [15, 9],
#  [15, 12],
#  [15, 15],
#  [15, 18],
#  [15, 21],
#  [15, 24],
#  [15, 27],
#  [18, 3],
#  [18, 6],
#  [18, 9],
#  [18, 12],
#  [18, 15],
#  [18, 18],
#  [18, 21],
#  [18, 24],
#  [18, 27],
#  [21, 3],
#  [21, 6],
#  [21, 9],
#  [21, 12],
#  [21, 15],
#  [21, 18],
#  [21, 21],
#  [21, 24],
#  [21, 27],
#  [24, 3],
#  [24, 6],
#  [24, 9],
#  [24, 12],
#  [24, 15],
#  [24, 18],
#  [24, 21],
#  [24, 24],
#  [24, 27],
#  [27, 3],
#  [27, 6],
#  [27, 9],
#  [27, 12],
#  [27, 15],
#  [27, 18],
#  [27, 21],
#  [27, 24],
#  [27, 27],
#  [30, 3],
#  [30, 6],
#  [30, 9],
#  [30, 12],
#  [30, 15],
#  [30, 18],
#  [30, 21],
#  [30, 24],
#  [30, 27],
#  [33, 3],
#  [33, 6],
#  [33, 9],
#  [33, 12],
#  [33, 15],
#  [33, 18],
#  [33, 21],
#  [33, 24],
#  [33, 27],
#  [36, 3],
#  [36, 6],
#  [36, 9],
#  [36, 12],
#  [36, 15],
#  [36, 18],
#  [36, 21],
#  [36, 24],
#  [36, 27],
#  [39, 3],
#  [39, 6],
#  [39, 9],
#  [39, 12],
#  [39, 15],
#  [39, 18],
#  [39, 21],
#  [39, 24],
#  [39, 27],
#  [42, 3],
#  [42, 6],
#  [42, 9],
#  [42, 12],
#  [42, 15],
#  [42, 18],
#  [42, 21],
#  [42, 24],
#  [42, 27],
#  [45, 3],
#  [45, 6],
#  [45, 9],
#  [45, 12],
#  [45, 15],
#  [45, 18],
#  [45, 21],
#  [45, 24],
#  [45, 27],
#  [48, 3],
#  [48, 6],
#  [48, 9],
#  [48, 12],
#  [48, 15],
#  [48, 18],
#  [48, 21],
#  [48, 24],
#  [48, 27],
#  [51, 3],
#  [51, 6],
#  [51, 9],
#  [51, 12],
#  [51, 15],
#  [51, 18],
#  [51, 21],
#  [51, 24],
#  [51, 27],
#  [54, 3],
#  [54, 6],
#  [54, 9],
#  [54, 12],
#  [54, 15],
#  [54, 18],
#  [54, 21],
#  [54, 24],
#  [54, 27],
#  [57, 3],
#  [57, 6],
#  [57, 9],
#  [57, 12],
#  [57, 15],
#  [57, 18],
#  [57, 21],
#  [57, 24],
#  [57, 27],
#  [60, 3],
#  [60, 6],
#  [60, 9],
#  [60, 12],
#  [60, 15],
#  [60, 18],
#  [60, 21],
#  [60, 24],
#  [60, 27],
#  [63, 3],
#  [63, 6],
#  [63, 9],
#  [63, 12],
#  [63, 15],
#  [63, 18],
#  [63, 21],
#  [63, 24],
#  [63, 27],
#  [66, 3],
#  [66, 6],
#  [66, 9],
#  [66, 12],
#  [66, 15],
#  [66, 18],
#  [66, 21],
#  [66, 24],
#  [66, 27],
#  [69, 3],
#  [69, 6],
#  [69, 9],
#  [69, 12],
#  [69, 15],
#  [69, 18],
#  [69, 21],
#  [69, 24],
#  [69, 27],
#  [72, 3],
#  [72, 6],
#  [72, 9],
#  [72, 12],
#  [72, 15],
#  [72, 18],
#  [72, 21],
#  [72, 24],
#  [72, 27],
#  [75, 3],
#  [75, 6],
#  [75, 9],
#  [75, 12],
#  [75, 15],
#  [75, 18],
#  [75, 21],
#  [75, 24],
#  [75, 27],
#  [78, 3],
#  [78, 6],
#  [78, 9],
#  [78, 12],
#  [78, 15],
#  [78, 18],
#  [78, 21],
#  [78, 24],
#  [78, 27],
#  [81, 3],
#  [81, 6],
#  [81, 9],
#  [81, 12],
#  [81, 15],
#  [81, 18],
#  [81, 21],
#  [81, 24],
#  [81, 27],
#  [84, 3],
#  [84, 6],
#  [84, 9],
#  [84, 12],
#  [84, 15],
#  [84, 18],
#  [84, 21],
#  [84, 24],
#  [84, 27],
#  [87, 3],
#  [87, 6],
#  [87, 9],
#  [87, 12],
#  [87, 15],
#  [87, 18],
#  [87, 21],
#  [87, 24],
#  [87, 27],
#  [90, 3],
#  [90, 6],
#  [90, 9],
#  [90, 12],
#  [90, 15],
#  [90, 18],
#  [90, 21],
#  [90, 24],
#  [90, 27],
#  [93, 3],
#  [93, 6],
#  [93, 9],
#  [93, 12],
#  [93, 15],
#  [93, 18],
#  [93, 21],
#  [93, 24],
#  [93, 27],
#  [96, 3],
#  [96, 6],
#  [96, 9],
#  [96, 12],
#  [96, 15],
#  [96, 18],
#  [96, 21],
#  [96, 24],
#  [96, 27],
#  [99, 3],
#  [99, 6],
#  [99, 9],
#  [99, 12],
#  [99, 15],
#  [99, 18],
#  [99, 21],
#  [99, 24],
#  [99, 27],
#  [102, 3],
#  [102, 6],
#  [102, 9],
#  [102, 12],
#  [102, 15],
#  [102, 18],
#  [102, 21],
#  [102, 24],
#  [102, 27],
#  [105, 3],
#  [105, 6],
#  [105, 9],
#  [105, 12],
#  [105, 15],
#  [105, 18],
#  [105, 21],
#  [105, 24],
#  [105, 27],
#  [108, 3],
#  [108, 6],
#  [108, 9],
#  [108, 12],
#  [108, 15],
#  [108, 18],
#  [108, 21],
#  [108, 24],
#  [108, 27],
#  [111, 3],
#  [111, 6],
#  [111, 9],
#  [111, 12],
#  [111, 15],
#  [111, 18],
#  [111, 21],
#  [111, 24],
#  [111, 27],
#  [114, 3],
#  [114, 6],
#  [114, 9],
#  [114, 12],
#  [114, 15],
#  [114, 18],
#  [114, 21],
#  [114, 24],
#  [114, 27],
#  [117, 3],
#  [117, 6],
#  [117, 9],
#  [117, 12],
#  [117, 15],
#  [117, 18],
#  [117, 21],
#  [117, 24],
#  [117, 27],
#  [120, 3],
#  [120, 6],
#  [120, 9],
#  [120, 12],
#  [120, 15],
#  [120, 18],
#  [120, 21],
#  [120, 24],
#  [120, 27],
#  [123, 3],
#  [123, 6],
#  [123, 9],
#  [123, 12],
#  [123, 15],
#  [123, 18],
#  [123, 21],
#  [123, 24],
#  [123, 27],
#  [126, 3],
#  [126, 6],
#  [126, 9],
#  [126, 12],
#  [126, 15],
#  [126, 18],
#  [126, 21],
#  [126, 24],
#  [126, 27],
#  [129, 3],
#  [129, 6],
#  [129, 9],
#  [129, 12],
#  [129, 15],
#  [129, 18],
#  [129, 21],
#  [129, 24],
#  [129, 27],
#  [132, 3],
#  [132, 6],
#  [132, 9],
#  [132, 12],
#  [132, 15],
#  [132, 18],
#  [132, 21],
#  [132, 24],
#  [132, 27],
#  [135, 3],
#  [135, 6],
#  [135, 9],
#  [135, 12],
#  [135, 15],
#  [135, 18],
#  [135, 21],
#  [135, 24],
#  [135, 27],
#  [138, 3],
#  [138, 6],
#  [138, 9],
#  [138, 12],
#  [138, 15],
#  [138, 18],
#  [138, 21],
#  [138, 24],
#  [138, 27],
#  [141, 3],
#  [141, 6],
#  [141, 9],
#  [141, 12],
#  [141, 15],
#  [141, 18],
#  [141, 21],
#  [141, 24],
#  [141, 27],
#  [144, 3],
#  [144, 6],
#  [144, 9],
#  [144, 12],
#  [144, 15],
#  [144, 18],
#  [144, 21],
#  [144, 24],
#  [144, 27],
#  [147, 3],
#  [147, 6],
#  [147, 9],
#  [147, 12],
#  [147, 15],
#  [147, 18],
#  [147, 21],
#  [147, 24],
#  [147, 27],
#  [150, 3],
#  [150, 6],
#  [150, 9],
#  [150, 12],
#  [150, 15],
#  [150, 18],
#  [150, 21],
#  [150, 24],
#  [150, 27],
#  [153, 3],
#  [153, 6],
#  [153, 9],
#  [153, 12],
#  [153, 15],
#  [153, 18],
#  [153, 21],
#  [153, 24],
#  [153, 27],
#  [156, 3],
#  [156, 6],
#  [156, 9],
#  [156, 12],
#  [156, 15],
#  [156, 18],
#  [156, 21],
#  [156, 24],
#  [156, 27],
#  [159, 3],
#  [159, 6],
#  [159, 9],
#  [159, 12],
#  [159, 15],
#  [159, 18],
#  [159, 21],
#  [159, 24],
#  [159, 27],
#  [162, 3],
#  [162, 6],
#  [162, 9],
#  [162, 12],
#  [162, 15],
#  [162, 18],
#  [162, 21],
#  [162, 24],
#  [162, 27],
#  [165, 3],
#  [165, 6],
#  [165, 9],
#  [165, 12],
#  [165, 15],
#  [165, 18],
#  [165, 21],
#  [165, 24],
#  [165, 27],
#  [168, 3],
#  [168, 6],
#  [168, 9],
#  [168, 12],
#  [168, 15],
#  [168, 18],
#  [168, 21],
#  [168, 24],
#  [168, 27],
#  [171, 3],
#  [171, 6],
#  [171, 9],
#  [171, 12],
#  [171, 15],
#  [171, 18],
#  [171, 21],
#  [171, 24],
#  [171, 27],
#  [174, 3],
#  [174, 6],
#  [174, 9],
#  [174, 12],
#  [174, 15],
#  [174, 18],
#  [174, 21],
#  [174, 24],
#  [174, 27],
#  [177, 3],
#  [177, 6],
#  [177, 9],
#  [177, 12],
#  [177, 15],
#  [177, 18],
#  [177, 21],
#  [177, 24],
#  [177, 27],
#  [180, 3],
#  [180, 6],
#  [180, 9],
#  [180, 12],
#  [180, 15],
#  [180, 18],
#  [180, 21],
#  [180, 24],
#  [180, 27],
#  [183, 3],
#  [183, 6],
#  [183, 9],
#  [183, 12],
#  [183, 15],
#  [183, 18],
#  [183, 21],
#  [183, 24],
#  [183, 27],
#  [186, 3],
#  [186, 6],
#  [186, 9],
#  [186, 12],
#  [186, 15],
#  [186, 18],
#  [186, 21],
#  [186, 24],
#  [186, 27],
#  [189, 3],
#  [189, 6],
#  [189, 9],
#  [189, 12],
#  [189, 15],
#  [189, 18],
#  [189, 21],
#  [189, 24],
#  [189, 27],
#  [192, 3],
#  [192, 6],
#  [192, 9],
#  [192, 12],
#  [192, 15],
#  [192, 18],
#  [192, 21],
#  [192, 24],
#  [192, 27],
#  [195, 3],
#  [195, 6],
#  [195, 9],
#  [195, 12],
#  [195, 15],
#  [195, 18],
#  [195, 21],
#  [195, 24],
#  [195, 27],
#  [198, 3],
#  [198, 6],
#  [198, 9],
#  [198, 12],
#  [198, 15],
#  [198, 18],
#  [198, 21],
#  [198, 24],
#  [198, 27],
#  [201, 3],
#  [201, 6],
#  [201, 9],
#  [201, 12],
#  [201, 15],
#  [201, 18],
#  [201, 21],
#  [201, 24],
#  [201, 27],
#  [204, 3],
#  [204, 6],
#  [204, 9],
#  [204, 12],
#  [204, 15],
#  [204, 18],
#  [204, 21],
#  [204, 24],
#  [204, 27],
#  [207, 3],
#  [207, 6],
#  [207, 9],
#  [207, 12],
#  [207, 15],
#  [207, 18],
#  [207, 21],
#  [207, 24],
#  [207, 27],
#  [210, 3],
#  [210, 6],
#  [210, 9],
#  [210, 12],
#  [210, 15],
#  [210, 18],
#  [210, 21],
#  [210, 24],
#  [210, 27],
#  [213, 3],
#  [213, 6],
#  [213, 9],
#  [213, 12],
#  [213, 15],
#  [213, 18],
#  [213, 21],
#  [213, 24],
#  [213, 27],
#  [216, 3],
#  [216, 6],
#  [216, 9],
#  [216, 12],
#  [216, 15],
#  [216, 18],
#  [216, 21],
#  [216, 24],
#  [216, 27],
#  [219, 3],
#  [219, 6],
#  [219, 9],
#  [219, 12],
#  [219, 15],
#  [219, 18],
#  [219, 21],
#  [219, 24],
#  [219, 27],
#  [222, 3],
#  [222, 6],
#  [222, 9],
#  [222, 12],
#  [222, 15],
#  [222, 18],
#  [222, 21],
#  [222, 24],
#  [222, 27],
#  [225, 3],
#  [225, 6],
#  [225, 9],
#  [225, 12],
#  [225, 15],
#  [225, 18],
#  [225, 21],
#  [225, 24],
#  [225, 27],
#  [228, 3],
#  [228, 6],
#  [228, 9],
#  [228, 12],
#  [228, 15],
#  [228, 18],
#  [228, 21],
#  [228, 24],
#  [228, 27],
#  [231, 3],
#  [231, 6],
#  [231, 9],
#  [231, 12],
#  [231, 15],
#  [231, 18],
#  [231, 21],
#  [231, 24],
#  [231, 27],
#  [234, 3],
#  [234, 6],
#  [234, 9],
#  [234, 12],
#  [234, 15],
#  [234, 18],
#  [234, 21],
#  [234, 24],
#  [234, 27],
#  [237, 3],
#  [237, 6],
#  [237, 9],
#  [237, 12],
#  [237, 15],
#  [237, 18],
#  [237, 21],
#  [237, 24],
#  [237, 27],
#  [240, 3],
#  [240, 6],
#  [240, 9],
#  [240, 12],
#  [240, 15],
#  [240, 18],
#  [240, 21],
#  [240, 24],
#  [240, 27],
#  [243, 3],
#  [243, 6],
#  [243, 9],
#  [243, 12],
#  [243, 15],
#  [243, 18],
#  [243, 21],
#  [243, 24],
#  [243, 27],
#  [246, 3],
#  [246, 6],
#  [246, 9],
#  [246, 12],
#  [246, 15],
#  [246, 18],
#  [246, 21],
#  [246, 24],
#  [246, 27],
#  [249, 3],
#  [249, 6],
#  [249, 9],
#  [249, 12],
#  [249, 15],
#  [249, 18],
#  [249, 21],
#  [249, 24],
#  [249, 27],
#  [252, 3],
#  [252, 6],
#  [252, 9],
#  [252, 12],
#  [252, 15],
#  [252, 18],
#  [252, 21],
#  [252, 24],
#  [252, 27],
#  [255, 3],
#  [255, 6],
#  [255, 9],
#  [255, 12],
#  [255, 15],
#  [255, 18],
#  [255, 21],
#  [255, 24],
#  [255, 27],
#  [258, 3],
#  [258, 6],
#  [258, 9],
#  [258, 12],
#  [258, 15],
#  [258, 18],
#  [258, 21],
#  [258, 24],
#  [258, 27],
#  [261, 3],
#  [261, 6],
#  [261, 9],
#  [261, 12],
#  [261, 15],
#  [261, 18],
#  [261, 21],
#  [261, 24],
#  [261, 27],
#  [264, 3],
#  [264, 6],
#  [264, 9],
#  [264, 12],
#  [264, 15],
#  [264, 18],
#  [264, 21],
#  [264, 24],
#  [264, 27],
#  [267, 3],
#  [267, 6],
#  [267, 9],
#  [267, 12],
#  [267, 15],
#  [267, 18],
#  [267, 21],
#  [267, 24],
#  [267, 27],
#  [270, 3],
#  [270, 6],
#  [270, 9],
#  [270, 12],
#  [270, 15],
#  [270, 18],
#  [270, 21],
#  [270, 24],
#  [270, 27],
#  [273, 3],
#  [273, 6],
#  [273, 9],
#  [273, 12],
#  [273, 15],
#  [273, 18],
#  [273, 21],
#  [273, 24],
#  [273, 27],
#  [276, 3],
#  [276, 6],
#  [276, 9],
#  [276, 12],
#  [276, 15],
#  [276, 18],
#  [276, 21],
#  [276, 24],
#  [276, 27],
#  [279, 3],
#  [279, 6],
#  [279, 9],
#  [279, 12],
#  [279, 15],
#  [279, 18],
#  [279, 21],
#  [279, 24],
#  [279, 27],
#  [282, 3],
#  [282, 6],
#  [282, 9],
#  [282, 12],
#  [282, 15],
#  [282, 18],
#  [282, 21],
#  [282, 24],
#  [282, 27],
#  [285, 3],
#  [285, 6],
#  [285, 9],
#  [285, 12],
#  [285, 15],
#  [285, 18],
#  [285, 21],
#  [285, 24],
#  [285, 27],
#  [288, 3],
#  [288, 6],
#  [288, 9],
#  [288, 12],
#  [288, 15],
#  [288, 18],
#  [288, 21],
#  [288, 24],
#  [288, 27],
#  [291, 3],
#  [291, 6],
#  [291, 9],
#  [291, 12],
#  [291, 15],
#  [291, 18],
#  [291, 21],
#  [291, 24],
#  [291, 27],
#  [294, 3],
#  [294, 6],
#  [294, 9],
#  [294, 12],
#  [294, 15],
#  [294, 18],
#  [294, 21],
#  [294, 24],
#  [294, 27],
#  [297, 3],
#  [297, 6],
#  [297, 9],
#  [297, 12],
#  [297, 15],
#  [297, 18],
#  [297, 21],
#  [297, 24],
#  [297, 27]]

# %%
def get_pairs_done(output_file):
    pairs_done = np.loadtxt(output_file, usecols=(0,1))
    return pairs_done

# %%
pairs_done = get_pairs_done('error_function.txt')

# %%
pairs_done
# Out:
# array([[ 12.,   9.],
#        [ 12.,  12.],
#        [ 12.,   6.],
#        ...,
#        [270.,   3.],
#        [267.,   3.],
#        [ 12.,   3.]])

# %%
pairs_done
# Out:
# array([[ 12.,   9.],
#        [ 12.,  12.],
#        [ 12.,   6.],
#        ...,
#        [270.,   3.],
#        [267.,   3.],
#        [ 12.,   3.]])

# %%
# define the error function 2 param modes
def error_function(n_LF, n_HF):
    eta = 11.20294568777112
    '''rho = pm.Uniform("rho", lower=0, upper=10)
    beta_L = pm.Uniform("beta_L", lower=0, upper=3)
    beta_H = pm.Uniform("beta_H", lower=0, upper=6)'''
    rho = 34422.595850790254
    beta_L = 1.1406839520015446
    beta_H = 4.145389781446169
    # rho_2 = pm.Uniform("rho_2", lower=0, upper=1)
    beta_H2 = 2.713544143928366
    # alpha_1 = pm.Normal("alpha_1", mu=10, sigma=5)
    alpha_L = 7.8176404049598816
    alpha_1 = 18.553167013696203
    alpha_2 = 7.5153891398955235

    sigma_lg_Phi = 0.21450697746101002   # standard deviation of the log of the error function
    # return 10**(np.log10(eta) + np.log10((rho / (n_LF**(beta_L) * n_HF**(beta_H)) + (1 - rho) / (alpha + n_HF**(beta_H2)))))
    lg_Phi = np.log10(eta) + np.log10(rho / ( (n_LF + n_HF) * (n_LF + alpha_L)**(beta_L-1) * (n_HF + alpha_1)**(beta_H-1) ) + 1 / (alpha_2 + n_HF)**(beta_H2))
    
    mode_Phi = 10**lg_Phi * np.exp(-sigma_lg_Phi**2 * (np.log(10))**2)
    mean_Phi = 10**lg_Phi * np.exp(1/2 * (sigma_lg_Phi * np.log(10))**2)
    median_Phi = 10**lg_Phi
    return mean_Phi

# %%
# naive lg_Phi
def error_function_old(n_LF, n_HF):
    eta = 0.7947996701660118
    '''rho = pm.Uniform("rho", lower=0, upper=10)
    beta_L = pm.Uniform("beta_L", lower=0, upper=3)
    beta_H = pm.Uniform("beta_H", lower=0, upper=6)'''
    rho = 5.608704513443982
    beta_L = 1.2974943261842817
    beta_H = 1.5156154430804256

    sigma_lg_Phi = 0.30695835929339044	   # standard deviation of the log of the error function
    # return 10**(np.log10(eta) + np.log10((rho / (n_LF**(beta_L) * n_HF**(beta_H)) + (1 - rho) / (alpha + n_HF**(beta_H2)))))
    lg_Phi = np.log10(eta) + np.log10(rho / (n_LF**(beta_L)) + 1 / (n_HF**(beta_H)))
    
    mode_Phi = 10**lg_Phi * np.exp(-sigma_lg_Phi**2 * (np.log(10))**2)
    mean_Phi = 10**lg_Phi * np.exp(1/2 * (sigma_lg_Phi * np.log(10))**2)
    median_Phi = 10**lg_Phi
    return mean_Phi

# %%
# # define the error function 7 par means
# def error_function(n_LF, n_HF):
#     eta = 10.912	
#     '''rho = pm.Uniform("rho", lower=0, upper=10)
#     beta_L = pm.Uniform("beta_L", lower=0, upper=3)
#     beta_H = pm.Uniform("beta_H", lower=0, upper=6)'''
#     rho = 56564.792
#     beta_L = 1.077	
#     beta_H = 4.231	
#     # rho_2 = pm.Uniform("rho_2", lower=0, upper=1)
#     # beta_H2 = 3.486
#     # alpha_1 = pm.Normal("alpha_1", mu=10, sigma=5)
#     alpha_L = 8.261	
#     alpha_1 = 18.469
#     alpha_2 = 9.758

#     sigma_lg_Phi = 0.215	   # standard deviation of the log of the error function
#     # return 10**(np.log10(eta) + np.log10((rho / (n_LF**(beta_L) * n_HF**(beta_H)) + (1 - rho) / (alpha + n_HF**(beta_H2)))))
#     lg_Phi = np.log10(eta) + np.log10(rho / ( (n_LF + n_HF) * (n_LF + alpha_L)**(beta_L-1) * (n_HF + alpha_1)**(beta_H-1) ) + 1 / (alpha_2 + n_HF)**(beta_H))
    
#     mode_Phi = 10**lg_Phi * np.exp(-sigma_lg_Phi**2 * (np.log(10))**2)
#     mean_Phi = 10**lg_Phi * np.exp(1/2 * (sigma_lg_Phi * np.log(10))**2)
#     median_Phi = 10**lg_Phi
#     return mean_Phi

# %%
# distinct colors
colors = plt.cm.viridis(np.linspace(0, 1, len(X[0])))

# plot the error function as curves
for i in range(len(X[0])):
    plt.plot(Y[:,0], Z[:, i], color=colors[i],label=r'$n_\mathrm{HF}=$' + str(int(X[0, i])))
# plot the error function as curves for different n_HF
for i in range(len(X[0])):
    plt.plot(Y[:,0], error_function(Y[:,0], X[0,i]), '--', color=colors[i])

plt.plot([],[], 'k--', label='estimated error func')
# adjust the legend location to outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# plt.legend()
plt.yscale('log')
# plt.ylim(1e-3, 2)
plt.xlabel(r'$n_\mathrm{LF}$')
plt.ylabel('Relative error')
plt.title('Error function')
plt.show()

# %%
plt.rcParams['font.family'] = 'Times New Roman'

# Set math font style
plt.rcParams['mathtext.fontset'] = 'cm'

fig, axes = plt.subplots(1, 2, figsize=(9, 4.5), sharex=True)

# Plot in the first panel
for i in range(len(X[0])):
    axes[0].plot(Y[:,0], Z[:, i], color=colors[i],label= str(int(X[0, i])))
# plot the error function as curves for different n_HF
for i in range(len(X[0])):
    axes[0].plot(Y[:,0], error_function(Y[:,0], X[0,i]), '--', color=colors[i])
axes[0].set_yscale('log')
axes[0].set_xlabel(r'$n_\mathrm{L}$')
axes[0].set_ylabel('Prediction error')
axes[0].set_title(r'$\left< \Phi\right>\ \mathrm{and}\ \left< \hat\Phi_\mathrm{obs}\right> $')
axes[0].plot([],[], 'k--', label='fit')

y_lower = 2.5e-3
y_upper = 4.5
axes[0].set_ylim(1e-3, 2)
axes[1].set_ylim(1e-3, 2)

# Plot in the second panel
# plot the error function as curves
for i in range(len(X[0])):
    axes[1].plot(Y[:,0], Z[:, i], color=colors[i],label=str(int(X[0, i])))
# plot the error function as curves for different n_HF
for i in range(len(X[0])):
    axes[1].plot(Y[:,0], error_function_old(Y[:,0], X[0,i]), '--', color=colors[i])
axes[1].set_yscale('log')
axes[1].set_xlabel(r'$n_\mathrm{L}$')
# axes[1].set_ylabel('Relative error')
axes[1].set_title(r'$\left< \Phi_\mathrm{old}\right>\ \mathrm{and}\ \left< \hat\Phi_\mathrm{obs}\right>$')
axes[0].legend(loc='center left', bbox_to_anchor=(1, 0.5), title=r'$n_\mathrm{H}$')
# Add gridlines to the plot
axes[0].grid(True)
axes[1].grid(True)
axes[1].set_yticks([.01, .1, 1], [' ', ' ', ' '])
# Adjust the spacing between subplots
plt.tight_layout()
# Adjust the spacing between subplots
plt.subplots_adjust(wspace=0.21)

# Show the figure
# plt.show()
plt.savefig('error_function.pdf',bbox_inches='tight')
