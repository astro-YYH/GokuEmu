# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import glob
from scipy.interpolate import interp1d
# from plot_funcs import *
from matplotlib import patches

# %%
def modecount_rebin(kk, pk, modes, minmodes=20, ndesired=200): #from MP-Gadget
    """Rebins a power spectrum so that there are sufficient modes in each bin"""
    assert np.all(kk) > 0
    logkk=np.log10(kk)
    mdlogk = (np.max(logkk) - np.min(logkk))/ndesired
    istart=iend=1
    count=0
    k_list=[kk[0]]
    pk_list=[pk[0]]
    targetlogk=mdlogk+logkk[istart]
    while iend < np.size(logkk)-1:
        count+=modes[iend]
        iend+=1
        if count >= minmodes and logkk[iend-1] >= targetlogk:
            pk1 = np.sum(modes[istart:iend]*pk[istart:iend])/count
            kk1 = np.sum(modes[istart:iend]*kk[istart:iend])/count
            k_list.append(kk1)
            pk_list.append(pk1)
            istart=iend
            targetlogk=mdlogk+logkk[istart]
            count=0
    k_list = np.array(k_list)
    pk_list = np.array(pk_list)
    return (k_list, pk_list)

def load_rebin(spec_file):
    k_raw, Pk_raw, modes = np.loadtxt(spec_file, usecols=(0,1,2), unpack=True)
    k, Pk = modecount_rebin(k_raw, Pk_raw, modes)
    return k, Pk

# %%
# relative difference
def rel_dif(x1, y1, x2, y2):
    # Transform x1, x2, y1, and y2 into log10 space
    log10_x1 = np.log10(x1)
    log10_x2 = np.log10(x2)
    log10_y1 = np.log10(y1)
    log10_y2 = np.log10(y2)

    # Define the common log10(x) range for interpolation
    common_log10_x_min = max(min(log10_x1), min(log10_x2))
    common_log10_x_max = min(max(log10_x1), max(log10_x2))
    common_log10_x = np.linspace(common_log10_x_min, common_log10_x_max, 100)

    # Interpolate log10_y1 and log10_y2 to the common log10_x grid
    interp_log10_y1 = interp1d(log10_x1, log10_y1, kind='linear')(common_log10_x)
    interp_log10_y2 = interp1d(log10_x2, log10_y2, kind='linear')(common_log10_x)

    # Transform interpolated log10 values back to the original space
    interp_y1 = 10**interp_log10_y1
    interp_y2 = 10**interp_log10_y2
    common_x = 10**common_log10_x  # Transform common_log10_x back to original x values

    # Compute (y2 - y1) / y1 in original space
    delta_y = (interp_y2 - interp_y1) / interp_y1
    return common_x, delta_y

# %%
def rMAE_av_cosmo(pred_parent, sim_parent, z):
    Ps_pred, nz_ind = load_pred(pred_parent, z)
    k_sim, Ps_sim = load_sim(sim_parent, z, nz_ind)
    k, rAEs = rel_MAEs(k_sim, Ps_sim, k_sim, Ps_pred)
    rMAE_av = np.mean(rAEs, axis=0)

    rAE_av_k = np.mean(rAEs, axis=1)
    print('z=', z, rAE_av_k)
    # print('z=', z, rAEs)
    # min and max
    rMAE_min, rMAE_max = np.min(rAEs, axis=0), np.max(rAEs, axis=0)
    return k, rMAE_av, rMAE_min, rMAE_max, rAEs

def load_pred(pred_parent, z):
    Ps_pred = []
    nz_ind = []  # for matching sim spectra
    for i in range(8):
        file_path = os.path.join(pred_parent, "matter_pow_z%s_l%d.txt" % (z, i))
        if os.path.exists(file_path):
            # print(f"The file {file_path} exists.")
            data = np.loadtxt(file_path,)
            data = data.transpose()
            P_pred = data[-1]
            Ps_pred.append(P_pred)
            nz_ind.append(i)
        else:
            print(f"The file {file_path} does not exist.")
            continue
    Ps_pred = np.array(Ps_pred)
    return Ps_pred, nz_ind

def load_sim(sim_parent, z, nz_ind):
    file_path = os.path.join(sim_parent, 'matter_power_564_Box1000_Part750_21_Box1000_Part3000_z%s/train_output_fidelity_1.txt' % z)
    k_path = os.path.join(sim_parent, 'matter_power_564_Box1000_Part750_21_Box1000_Part3000_z%s/kf.txt' % z)
    lg_Ps = np.loadtxt(file_path)
    lg_Ps = lg_Ps[nz_ind]
    Ps_sim = 10**lg_Ps
    lg_k = np.loadtxt(k_path, usecols=(0))
    k_sim = 10**lg_k
    return k_sim, Ps_sim


def rel_MAEs(x1, y1, x2, y2):
    # Transform x1, x2, y1, and y2 into log10 space
    log10_x1 = np.log10(x1)
    log10_x2 = np.log10(x2)
    log10_y1 = np.log10(y1)
    log10_y2 = np.log10(y2)

    # Define the common log10(x) range for interpolation
    common_log10_x_min = max(min(log10_x1), min(log10_x2))
    common_log10_x_max = min(max(log10_x1), max(log10_x2))
    common_log10_x = np.linspace(common_log10_x_min, common_log10_x_max, 100)

    # Interpolate log10_y1 and log10_y2 to the common log10_x grid
    interp_log10_y1 = interp1d(log10_x1, log10_y1, kind='linear')(common_log10_x)
    interp_log10_y2 = interp1d(log10_x2, log10_y2, kind='linear')(common_log10_x)

    # Transform interpolated log10 values back to the original space
    interp_y1 = 10**interp_log10_y1
    interp_y2 = 10**interp_log10_y2
    common_x = 10**common_log10_x  # Transform common_log10_x back to original x values

    # Compute (y2 - y1) / y1 in original space
    rMAE_y = np.abs((interp_y2 / interp_y1) - 1)
    return common_x, rMAE_y

# %%
# P_pred = np.loadtxt('matter_pow_z0_l0.txt', usecols=(2))

# %%
# relative
# sim_parent = "/work2/01317/yyang440/frontera/cosmo_11p_sims/data_for_emu" # frontera
sim_parent = "../data" 
pred_parent = './loo_upper/'

fig, ax = plt.subplots(figsize=(3.4,3.))
plt.rcParams['font.family'] = 'Nimbus Roman'

# Set math font style
plt.rcParams['mathtext.fontset'] = 'cm'

zs = np.array([0,0.2, 0.5, 1, 2, 3, 4, 9, 49, 99])
zs_str = ['0', '0.2', '0.5', '1', '2', '3', '4', '9', '49', '99']
a = 1/(1+zs)

color_list = ['green', 'blue', 'grey', 'purple', 'cyan', 'magenta']

# ax.plot([], [], color='black', label='HF')
# # ax.plot([], [], color='black', linestyle=':', label='L1')
# ax.plot([], [], color='black', linestyle='--', label='Linear')
rMAE_zs = []

for i, scale in enumerate(a):
    if i==6:
        break
    c = color_list[i]
    # k_L1, Pk_L1 = load_rebin(os.path.join(sim_L1, "output/powerspectrum-%.4f.txt" % scale))
    # k_L2, Pk_L2 = load_rebin(os.path.join(sim_L2, "output/powerspectrum-%.4f.txt" % scale))
    k, rMAE, rMAE_min, rMAE_max, rAEs = rMAE_av_cosmo(pred_parent, sim_parent, zs_str[i])
    rMAE_zs.append(rMAE.mean())
    # k_HF, Pk_HF = load_rebin(os.path.join(sim_HF, "output/powerspectrum-%.4f.txt" % scale))
    # k_li, Pk_li = np.loadtxt(os.path.join(sim_HF, "camb_linear/ics_matterpow_%s.dat" % zs_str[i]), usecols=(0,1), unpack=True)

    ax.plot(k, rMAE/1e-2, color=c, label=r"$z=%.1f$" % zs[i])
    # ax.plot(k_li, Pk_li, '--', color=c)
    # individual
    for rAE in rAEs:
        ax.plot(k, rAE/1e-2, color=c, alpha=0.4)

    ax.fill_between(k, rMAE_min/1e-2, rMAE_max/1e-2, color=c, alpha=0.2)
    
rMAE_zs = np.array(rMAE_zs)
rMAE_zs_mean = rMAE_zs.mean()
print('average over k and z:', rMAE_zs_mean)
    # plt.loglog(k_HF, Pk_HF, color=c, label=r"$z=%.1f$" % zs[i])
    

    # if labels is not None:

# ax.set_ylim(.07,.5e5)
# ax.legend(loc='best')
# ax.set_yscale('log')
ax.set_ylabel(r'$\Phi_{\mathrm{rMAE}}\ (\%)$')
# plt.xlabel(r'$k\ (h\,\mathrm{Mpc}^{-1})$')
# plt.ylabel(r'$P(k)\ (h^{-3}\mathrm{Mpc}^3)$')
# ax.plot([], [], color='black', label='HF')
# ax.plot([], [], color='black', label='HF w.r.t. Linear')
# ax.plot([], [], color='black', linestyle='--', label='L2 w.r.t. HF')
ax.set_ylim(0., 10)
ax.set_xscale('log')
ax.set_xlabel(r'$k\ (h\,\mathrm{Mpc}^{-1})$')
# ax.set_ylabel(r'$(P_\mathrm{HF}-P_\mathrm{Li})/P_\mathrm{Li}$')

xlim1 = .02
xlim2 = 10
ax.set_xlim(xlim1, xlim2)

square = patches.Rectangle((xlim1, -0.0), xlim2-xlim1, 1, color='orange', alpha=.3, zorder=2, label=r'$1\%$')  # alpha ranges from 0 (transparent) to 1 (opaque)
# square1 = patches.Rectangle((xlim1, -0.01), xlim2-xlim1, 0.02, color='blue', alpha=.3, zorder=2, label=r'$1\%$')  # alpha ranges from 0 (transparent) to 1 (opaque)

# Add the square to the axes
ax.add_patch(square)
# ax.add_patch(square1)
ax.legend(loc='upper left')
# ax.set_yticks([-0.2,-.1,0,.1,.2])

# plt.xlim([0.005, 100])
# plt.ylim([.01,4e5])
# plt.ylim([-.3, .3])
plt.show()
# plt.savefig('matter_pow_nonl_linear_ratio.pdf', bbox_inches='tight')
# Out:
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# The file ./loo_upper/matter_pow_z0_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z0_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z0_l4.txt does not exist.
# The file ./loo_upper/matter_pow_z0_l7.txt does not exist.
# z= 0 [0.03045782 0.01609484 0.0438352  0.01371511]
# The file ./loo_upper/matter_pow_z0.2_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z0.2_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z0.2_l4.txt does not exist.
# The file ./loo_upper/matter_pow_z0.2_l7.txt does not exist.
# z= 0.2 [0.0369516  0.01624529 0.03287923 0.01817756]
# The file ./loo_upper/matter_pow_z0.5_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z0.5_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z0.5_l4.txt does not exist.
# The file ./loo_upper/matter_pow_z0.5_l5.txt does not exist.
# The file ./loo_upper/matter_pow_z0.5_l7.txt does not exist.
# z= 0.5 [0.03839718 0.02200698 0.01600774]
# The file ./loo_upper/matter_pow_z1_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z1_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z1_l5.txt does not exist.
# z= 1 [0.0321296  0.02134132 0.0362652  0.01752831 0.03767801]
# The file ./loo_upper/matter_pow_z2_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z2_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z2_l5.txt does not exist.
# z= 2 [0.03715794 0.02179669 0.04017819 0.01788365 0.0321303 ]
# The file ./loo_upper/matter_pow_z3_l0.txt does not exist.
# The file ./loo_upper/matter_pow_z3_l1.txt does not exist.
# The file ./loo_upper/matter_pow_z3_l2.txt does not exist.
# The file ./loo_upper/matter_pow_z3_l5.txt does not exist.
# The file ./loo_upper/matter_pow_z3_l6.txt does not exist.
# z= 3 [0.03281373 0.03936734 0.02480675]
# average over k and z: 0.028117819285305563
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.

# %%
# # lower

# # relative
# # sim_parent = "/work2/01317/yyang440/frontera/cosmo_11p_sims/data_for_emu" # frontera
# sim_parent = "/bigdata/birdlab/yyang440/cosmo_11p_sims/data_for_emu" # hpcc
# pred_parent = './'

# fig, ax = plt.subplots(figsize=(3.4,3.))
# plt.rcParams['font.family'] = 'Nimbus Roman'

# # Set math font style
# plt.rcParams['mathtext.fontset'] = 'cm'

# zs = np.array([0,0.2, 0.5, 1, 2, 3, 4, 9, 49, 99])
# zs_str = ['0', '0.2', '0.5', '1', '2', '3', '4', '9', '49', '99']
# a = 1/(1+zs)

# color_list = ['green', 'blue', 'grey', 'purple', 'cyan', 'magenta']

# # ax.plot([], [], color='black', label='HF')
# # # ax.plot([], [], color='black', linestyle=':', label='L1')
# # ax.plot([], [], color='black', linestyle='--', label='Linear')
# rMAE_zs = []

# for i, scale in enumerate(a):
#     if i==6:
#         break
#     c = color_list[i]
#     # k_L1, Pk_L1 = load_rebin(os.path.join(sim_L1, "output/powerspectrum-%.4f.txt" % scale))
#     # k_L2, Pk_L2 = load_rebin(os.path.join(sim_L2, "output/powerspectrum-%.4f.txt" % scale))
#     k, rMAE, rMAE_min, rMAE_max, rAEs = rMAE_av_cosmo(pred_parent, sim_parent, zs_str[i])
#     rMAE_zs.append(rMAE.mean())
#     # k_HF, Pk_HF = load_rebin(os.path.join(sim_HF, "output/powerspectrum-%.4f.txt" % scale))
#     # k_li, Pk_li = np.loadtxt(os.path.join(sim_HF, "camb_linear/ics_matterpow_%s.dat" % zs_str[i]), usecols=(0,1), unpack=True)

#     ax.plot(k, rMAE/1e-2, color=c, label=r"$z=%.1f$" % zs[i])
#     # ax.plot(k_li, Pk_li, '--', color=c)
#     # individual
#     for rAE in rAEs:
#         ax.plot(k, rAE/1e-2, color=c, alpha=0.4)

#     ax.fill_between(k, rMAE_min/1e-2, rMAE_max/1e-2, color=c, alpha=0.2)
    
# rMAE_zs = np.array(rMAE_zs)
# rMAE_zs_mean = rMAE_zs.mean()
# print('average over k and z:', rMAE_zs_mean)
#     # plt.loglog(k_HF, Pk_HF, color=c, label=r"$z=%.1f$" % zs[i])
    

#     # if labels is not None:

# # ax.set_ylim(.07,.5e5)
# # ax.legend(loc='best')
# # ax.set_yscale('log')
# ax.set_ylabel(r'$\Phi_{\mathrm{rMAE}}\ (\%)$')
# # plt.xlabel(r'$k\ (h\,\mathrm{Mpc}^{-1})$')
# # plt.ylabel(r'$P(k)\ (h^{-3}\mathrm{Mpc}^3)$')
# # ax.plot([], [], color='black', label='HF')
# # ax.plot([], [], color='black', label='HF w.r.t. Linear')
# # ax.plot([], [], color='black', linestyle='--', label='L2 w.r.t. HF')
# ax.set_ylim(0., 4.5)
# ax.set_xscale('log')
# ax.set_xlabel(r'$k\ (h\,\mathrm{Mpc}^{-1})$')
# # ax.set_ylabel(r'$(P_\mathrm{HF}-P_\mathrm{Li})/P_\mathrm{Li}$')

# xlim1 = .02
# xlim2 = 10
# ax.set_xlim(xlim1, xlim2)

# square = patches.Rectangle((xlim1, -0.0), xlim2-xlim1, 1, color='orange', alpha=.3, zorder=2, label=r'$1\%$')  # alpha ranges from 0 (transparent) to 1 (opaque)
# # square1 = patches.Rectangle((xlim1, -0.01), xlim2-xlim1, 0.02, color='blue', alpha=.3, zorder=2, label=r'$1\%$')  # alpha ranges from 0 (transparent) to 1 (opaque)

# # Add the square to the axes
# ax.add_patch(square)
# # ax.add_patch(square1)
# ax.legend(loc='upper left')
# # ax.set_yticks([-0.2,-.1,0,.1,.2])

# # plt.xlim([0.005, 100])
# # plt.ylim([.01,4e5])
# # plt.ylim([-.3, .3])
# plt.show()
# # plt.savefig('matter_pow_nonl_linear_ratio.pdf', bbox_inches='tight')
# Out:
# The file ./matter_pow_z0_l0.txt does not exist.
# The file ./matter_pow_z0_l1.txt does not exist.
# The file ./matter_pow_z0_l2.txt does not exist.
# The file ./matter_pow_z0_l3.txt does not exist.
# The file ./matter_pow_z0_l4.txt does not exist.
# The file ./matter_pow_z0_l5.txt does not exist.
# The file ./matter_pow_z0_l6.txt does not exist.
# The file ./matter_pow_z0_l7.txt does not exist.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 31
#      28 c = color_list[i]
#      29 # k_L1, Pk_L1 = load_rebin(os.path.join(sim_L1, "output/powerspectrum-%.4f.txt" % scale))
#      30 # k_L2, Pk_L2 = load_rebin(os.path.join(sim_L2, "output/powerspectrum-%.4f.txt" % scale))
# ---> 31 k, rMAE, rMAE_min, rMAE_max, rAEs = rMAE_av_cosmo(pred_parent, sim_parent, zs_str[i])
#      32 rMAE_zs.append(rMAE.mean())
#      33 # k_HF, Pk_HF = load_rebin(os.path.join(sim_HF, "output/powerspectrum-%.4f.txt" % scale))
#      34 # k_li, Pk_li = np.loadtxt(os.path.join(sim_HF, "camb_linear/ics_matterpow_%s.dat" % zs_str[i]), usecols=(0,1), unpack=True)
#
# Cell In[6], line 3, in rMAE_av_cosmo(pred_parent, sim_parent, z)
#       1 def rMAE_av_cosmo(pred_parent, sim_parent, z):
#       2     Ps_pred, nz_ind = load_pred(pred_parent, z)
# ----> 3     k_sim, Ps_sim = load_sim(sim_parent, z, nz_ind)
#       4     k, rAEs = rel_MAEs(k_sim, Ps_sim, k_sim, Ps_pred)
#       5     rMAE_av = np.mean(rAEs, axis=0)
#
# Cell In[6], line 35, in load_sim(sim_parent, z, nz_ind)
#      33 file_path = os.path.join(sim_parent, 'matter_power_564_Box1000_Part750_21_Box1000_Part3000_z%s/train_output_fidelity_1.txt' % z)
#      34 k_path = os.path.join(sim_parent, 'matter_power_564_Box1000_Part750_21_Box1000_Part3000_z%s/kf.txt' % z)
# ---> 35 lg_Ps = np.loadtxt(file_path)
#      36 lg_Ps = lg_Ps[nz_ind]
#      37 Ps_sim = 10**lg_Ps
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:1373, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1370 if isinstance(delimiter, bytes):
#    1371     delimiter = delimiter.decode('latin1')
# -> 1373 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1374             converters=converters, skiplines=skiprows, usecols=usecols,
#    1375             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1376             max_rows=max_rows, quote=quotechar)
#    1378 return arr
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:992, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     990     fname = os.fspath(fname)
#     991 if isinstance(fname, str):
# --> 992     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     993     if encoding is None:
#     994         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /bigdata/birdlab/yyang440/cosmo_11p_sims/data_for_emu/matter_power_564_Box1000_Part750_21_Box1000_Part3000_z0/train_output_fidelity_1.txt not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
# findfont: Font family 'Nimbus Roman' not found.
